# %%
import pandas as pd

# %%
temp = pd.read_csv('Temperature_Data/Temperature_NorthernAfrica.csv')

# %%
precip = pd.read_csv('Precipitation_Data/ModeledRainFall_NorthernAfrica.csv')

# %%
precip
# Out:
#                        Metric              Item   Region Partner Region  \
# 0      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 1      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 2      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 3      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 4      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 5      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 6      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 7      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 8      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 9      Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 10     Precipitation Quantity  Modeled rainfall  Algeria            NaN
# 11     Precipitation Quantity  Modeled rainfall  Algeria            NaN
# ...

# %%
temp
# Out:
#                   Metric                              Item   Region  \
# 0      Temperature Value  Daytime land surface temperature  Algeria
# 1      Temperature Value  Daytime land surface temperature  Algeria
# 2      Temperature Value  Daytime land surface temperature  Algeria
# 3      Temperature Value  Daytime land surface temperature  Algeria
# 4      Temperature Value  Daytime land surface temperature  Algeria
# 5      Temperature Value  Daytime land surface temperature  Algeria
# 6      Temperature Value  Daytime land surface temperature  Algeria
# 7      Temperature Value  Daytime land surface temperature  Algeria
# 8      Temperature Value  Daytime land surface temperature  Algeria
# 9      Temperature Value  Daytime land surface temperature  Algeria
# 10     Temperature Value  Daytime land surface temperature  Algeria
# 11     Temperature Value  Daytime land surface temperature  Algeria
# 12     Temperature Value  Daytime land surface temperature  Algeria
# ...
